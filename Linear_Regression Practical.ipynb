# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score,mean_squared_error, r2_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/house_price.csv')

# %%
df.head()
# Out:
#    Area in Sq/m    Price
# 0           500  2000000
# 1           550  2050000
# 2           600  3000000
# 3           650  3050000
# 4           700  4000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area in Sq/m  40 non-null     int64
#  1   Price         40 non-null     int64
# dtypes: int64(2)
# memory usage: 772.0 bytes

# %%
df.isnull().sum()
# Out:
# Area in Sq/m    0
# Price           0
# dtype: int64

# %%
X = df['Area in Sq/m']
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test.values.reshape(-1, 1))

# %%
print("Slope (m):", model.coef_[0])
print("Intercept (c):", model.intercept_)
# Out:
# Slope (m): 6088.8358386708
# Intercept (c): -737343.1763441255

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R² Score:", r2)
# Out:
# Mean Squared Error: 11751683367421.596
# R² Score: 0.8815792119973468

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X_test.values.flatten(), y=y_test.values, color='blue', label='Actual')
sns.lineplot(x=X_test.values.flatten(), y=y_pred, color='red', label='Predicted')
plt.xlabel('Area in Sq/m')
plt.ylabel('Price')
plt.title('Linear Regression - House Price Prediction')
plt.legend()
plt.show()

# %%
# add 30 records

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/house_price_random.csv')

# %%
df1.head()
# Out:
#    Area in Sq/m      Price
# 0         500.0  2000000.0
# 1         550.0  2050000.0
# 2         600.0  3000000.0
# 3         650.0  3050000.0
# 4         700.0  4000000.0

# %%
df1.tail()
# Out:
#     Area in Sq/m       Price
# 37        4862.0  39850000.0
# 38         523.0   2200000.0
# 39         699.0   4000000.0
# 40           NaN         NaN
# 41           NaN         NaN

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area in Sq/m  40 non-null     float64
#  1   Price         40 non-null     float64
# dtypes: float64(2)
# memory usage: 804.0 bytes

# %%
X1 = df['Area in Sq/m']
y1 = df['Price']

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.3, random_state=42)

# %%
model1 = LinearRegression()

# %%
model1.fit(X1_train.values.reshape(-1, 1), y1_train)
# Out:
# LinearRegression()

# %%
y1_pred = model1.predict(X1_test.values.reshape(-1, 1))

# %%
print("Slope (m):", model1.coef_[0])
print("Intercept (c):", model1.intercept_)
# Out:
# Slope (m): 6088.8358386708
# Intercept (c): -737343.1763441255

# %%
mse1 = mean_squared_error(y1_test, y1_pred)
r2_1 = r2_score(y1_test, y1_pred)
print("Mean Squared Error:", mse1)
print("R² Score:", r2_1)
# Out:
# Mean Squared Error: 11751683367421.596
# R² Score: 0.8815792119973468

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X1_test.values.flatten(), y=y1_test.values, color='blue', label='Actual')
sns.lineplot(x=X1_test.values.flatten(), y=y1_pred, color='red', label='Predicted')
plt.xlabel('Area in Sq/m')
plt.ylabel('Price')
plt.title('Linear Regression - House Price Prediction')
plt.legend()
plt.show()
